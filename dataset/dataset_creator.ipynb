# %% [markdown]
# # Author: Tim Harmling
# - **Description:** Creates a Dataset that can be used from our Handwriting Model with *.jpg and *.txt files. The *.txt files contain the text of the handwritten text in the image. The *.jpg files contain the cropped images of the handwritten text.

# %% [markdown]
# # Create Dataset

# %%
import os
import xml.etree.ElementTree as ET
from builtins import print

import tensorflow as tf
# import keras_cv

from tqdm.auto import tqdm
from tensorflow import keras
#from keras_cv import bounding_box
#from keras_cv import visualization
from keras.models import load_model
import numpy as np
from keras.models import Sequential, model_from_json
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
from keras.callbacks import EarlyStopping
import re

# %%
path = "dataset/xml"

# Get all XML file paths in path_annot and sort them
xml_files = sorted(
    [
        os.path.join(path, file_name)
        for file_name in os.listdir(path)
        if file_name.endswith(".xml")
    ]
)
 
# Get all JPEG image file paths in path_images and sort them
jpg_files = sorted(
    [
        os.path.join(path, file_name)
        for file_name in os.listdir(path)
        if file_name.endswith(".jpg")
    ]
)

# %%
def create_box(bbox):
    xmin = float(bbox.find("xmin").text)
    ymin = float(bbox.find("ymin").text)
    xmax = float(bbox.find("xmax").text)
    ymax = float(bbox.find("ymax").text)
    return [xmin, ymin, xmax, ymax]

# %%
def parse_annotation_fake(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    image_name = root.find("filename").text
    image_path = f'dataset/images/{image_name}'

    boxes = []
    classes = []
    main_classes = []
    sub_classes = []
    main_boxes = []
    sub_boxes = []
    values = []
    
    for obj in root.iter("object"):
        cls = obj.find("name").text
        classes.append(cls)
        
        bbox = obj.find("bndbox")
        boxes.append(create_box(bbox))
    
    
        attributes = obj.findall("attributes/attribute")
        for attribute in attributes:
            value_element = attribute.find("value")
            value = value_element.text
            if value is None:
                continue
            elif value is None or value.lower() in ["true", "false"]:
                continue
            
            # Versuche, den Wert in einen Float zu konvertieren
            try:
                float_value = float(value)
                int_value = int(float_value)
                values.append(str(int_value))  # Hier wird der Integer in einen String umgewandelt
            except ValueError:
                # Wenn die Konvertierung fehlschlägt, füge den originalen Wert zur Liste hinzu
                values.append(value)
            break
        
        bbox = obj.find("bndbox")
        sub_boxes.append(create_box(bbox))
        sub_classes.append(cls)
    return image_path, sub_boxes, sub_classes, values

# %%
from collections import namedtuple
ImageInfo = namedtuple('ImageInfo', ['path', 'boxes', 'values', 'classes'])
image_list = []
for xml_file in tqdm(xml_files): 
    image_path, boxes, classes, values = parse_annotation_fake(xml_file)
    image_list.append(ImageInfo(image_path, boxes, values, classes))

# %% [markdown]
# ### Crop ROI

# %%
import cv2
def crop(xmin, ymin, xmax, ymax, image_path, crop_left_percent, crop_bottom_percent):
    image = cv2.imread(image_path)
    crop_left = int((xmax-xmin) * crop_left_percent)
    crop_bottom = int((ymax-ymin) * crop_bottom_percent)

    cropped_image = image[int(ymin):int(ymax)-crop_bottom, int(xmin)+crop_left:int(xmax)]
    if cropped_image.size == 0:
        print("Cropped image is empty")
        return None
    return cropped_image

# %%
save_path_crops = "dataset/dataset_training"

# %%
cropping_params = {
    "ad_erzieher_name":         {"left": 0.1, "bottom": 0},
    "ad_erzieher_vorname":      {"left": 0.125, "bottom": 0},
    "ad_erzieher_tel":          {"left": 0.2, "bottom": 0},
    "ad_erzieher_email":        {"left": 0.1, "bottom": 0},
    "schueler_name":            {"left": 0.1, "bottom": 0},
    "schueler_vorname":         {"left": 0.15, "bottom": 0},
    "schueler_klasse":          {"left": 0.125, "bottom": 0},
    "ad_neue_ad_str_haus_nr":   {"left": 0.275, "bottom": 0},
    "ad_neue_ad_plz":           {"left": 0.175, "bottom": 0},
    "ad_neue_ad_stadt":         {"left": 0.1, "bottom": 0},
    "ad_schueler_datum":        {"left": 0.2, "bottom": 0},
    "ag_auswahl_wahl_1":        {"left": 0.15, "bottom": 0},
    "ag_auswahl_wahl_2":        {"left": 0.15, "bottom": 0},
    "ag_auswahl_wahl_3":        {"left": 0.15, "bottom": 0},
    "ag_schueler_datum":        {"left": 0.3, "bottom": 0},
    #"ad_schueler_unterschrift": {"left": 0.2, "bottom": 0.4}, 
    #"ag_schueler_unterschrift": {"left": 0.2, "bottom": 0.4}, 
}

# %%
for index, image in enumerate(image_list):
    boxes = image.boxes
    for i, box in enumerate(boxes):
        xmin, ymin, xmax, ymax = np.array(box)
        crop_left_percent = 0
        crop_bottom_percent = 0
        if image.classes[i] in cropping_params:
            params = cropping_params[image.classes[i]]
            crop_left_percent = float(params["left"])
            crop_bottom_percent = float(params["bottom"])
        else:
            continue

        imgCropped = crop(xmin, ymin, xmax, ymax, image.path, crop_left_percent, crop_bottom_percent)
        if imgCropped is not None:
            if image.values[i] == "0":
                continue
            img_file_path = f"{save_path_crops}/{index}_{i}.jpg"
            txt_file_path = f"{save_path_crops}/{index}_{i}.txt"
            cv2.imwrite(img_file_path, imgCropped)
            with open(txt_file_path, 'w', encoding='utf-8') as file:
                image.values[i] = image.values[i].replace(" ", "|")
                file.write(image.values[i])
                print(f"{image.classes[i]}: {image.values[i]}")
# Out:
# ad_erzieher_name: Lüdtke
# ad_erzieher_vorname: Markus
# ad_erzieher_tel: 3366806
# ad_erzieher_email: luedtke@gmx.de
# schueler_name: Lüdtke
# schueler_vorname: Mila
# schueler_klasse: 6b
# ad_neue_ad_str_haus_nr: Schumannstrasse|10
# ad_neue_ad_plz: 28213
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 15.04.2024
# ad_schueler_datum: 17.04.2024
# ad_neue_ad_stadt: Bremen
# ad_neue_ad_plz: 28309
# ad_neue_ad_str_haus_nr: Marschstrasse|2
# ad_erzieher_email: merschristian@gmx.de
# ad_erzieher_tel: 4349733
# ad_erzieher_vorname: Christian
# ad_erzieher_name: Mersmann
# schueler_name: Mersmann
# schueler_vorname: Finn
# schueler_klasse: 6B
# schueler_klasse: 6b
# schueler_vorname: Luca
# schueler_name: Fabisch
# ad_erzieher_name: Fabisch
# ad_erzieher_vorname: Timo
# ad_erzieher_tel: 9383071
# ad_erzieher_email: fabisch@gmx.de
# ad_neue_ad_str_haus_nr: Orchideenweg|12
# ad_neue_ad_plz: 28219
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 18.04.2024
# ad_erzieher_name: Jacob
# ad_erzieher_vorname: Timo
# schueler_name: Jacob
# schueler_vorname: Irena
# schueler_klasse: 8d
# ad_erzieher_tel: 6930088
# ad_erzieher_email: tjac@posteo.de
# ad_neue_ad_str_haus_nr: Emschweg|4
# ad_neue_ad_plz: 28205
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 05.04.2024
# ad_erzieher_name: Stevens
# ad_erzieher_vorname: Dennis
# ad_erzieher_tel: 3719716
# ad_erzieher_email: d.stevens@web.de
# schueler_name: Stevens
# schueler_vorname: Tyler
# schueler_klasse: 8d
# ad_neue_ad_str_haus_nr: Eisenachener|Straße|3
# ad_neue_ad_plz: 28205
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 05.04.2024
# schueler_vorname: Roth
# schueler_klasse: 6B
# ad_erzieher_name: Emma
# ad_erzieher_vorname: Christine
# ad_erzieher_tel: 5757633
# ad_erzieher_email: c-emma@web.de
# ad_neue_ad_plz: 28201
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 12.04.2024
# schueler_name: Emma
# ad_neue_ad_str_haus_nr: Kornstraße|69
# schueler_vorname: Emil
# schueler_klasse: 12A
# ad_erzieher_name: Liebelt
# ad_erzieher_vorname: Anja
# ad_erzieher_tel: 2106865
# ad_erzieher_email: liebeanja@web.de
# ad_neue_ad_str_haus_nr: Borgfelder|Heerstraße|36
# ad_neue_ad_plz: 28357
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 22.04.2024
# schueler_name: Liebelt
# schueler_vorname: Verena
# schueler_klasse: 12A
# ad_erzieher_name: Reising
# ad_erzieher_vorname: Yvonne
# ad_erzieher_tel: 6944163
# ad_erzieher_email: reising@web.de
# ad_neue_ad_str_haus_nr: Grüsemannallee|30
# ad_neue_ad_plz: 28213
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 20.04.2024
# schueler_name: Reising
# schueler_vorname: Sören
# schueler_klasse: 6B
# ad_erzieher_name: Weber
# ad_erzieher_vorname: Maren
# ad_erzieher_tel: 7561416
# ad_erzieher_email: familieweber@web.de
# ad_neue_ad_str_haus_nr: Helmer|23
# ad_neue_ad_plz: 28359
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 11.04.2024
# schueler_name: Weber
# ad_neue_ad_stadt: Bremen
# ad_erzieher_name: Wollmann
# ad_erzieher_vorname: Simone
# ad_erzieher_tel: 2738386
# ad_erzieher_email: wolli@web.de
# schueler_name: Wollmann
# schueler_vorname: Mia
# schueler_klasse: 6B
# ad_neue_ad_str_haus_nr: Ledaweg|23
# ad_neue_ad_plz: 28359
# ad_schueler_datum: 09.04.2024
# ad_erzieher_name: Huhn
# ad_erzieher_vorname: Sandra
# ad_erzieher_tel: 1625128
# ad_erzieher_email: huhns@web.de
# schueler_name: Huhn
# schueler_vorname: Fabian
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Aachener|Straße|5
# ad_neue_ad_plz: 28327
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 21.04.2024
# schueler_name: Dussen
# ad_erzieher_name: Dussen
# ad_erzieher_vorname: Julia
# ad_erzieher_tel: 7214608
# ad_erzieher_email: dussduss@gmx.de
# schueler_vorname: Gunnar
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Cuxhavener|Straße|4
# ad_neue_ad_plz: 28357
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 17.04.2024
# ad_schueler_datum: 06.04.2024
# ad_erzieher_name: Anders
# ad_erzieher_vorname: Claudia
# ad_erzieher_tel: 8315938
# ad_erzieher_email: andersc@gmx.de
# schueler_name: Anders
# schueler_vorname: Iwona
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Dahlwas|19
# ad_neue_ad_plz: 28307
# ad_neue_ad_stadt: Bremen
# ad_neue_ad_stadt: Bremen
# schueler_vorname: Huber
# schueler_name: Patrick
# schueler_klasse: 6B
# ad_erzieher_name: Huber
# ad_erzieher_vorname: Jan
# ad_erzieher_tel: 4650819
# ad_erzieher_email: huberj@gmx.de
# ad_neue_ad_plz: 28211
# ad_neue_ad_str_haus_nr: Geisbergstraße|5
# ad_neue_ad_stadt: Bremen
# ad_erzieher_name: Huber
# ad_erzieher_vorname: Jan
# ad_erzieher_tel: 4650819
# ad_erzieher_email: huberj@gmx.de
# schueler_name: Huber
# schueler_vorname: Patrick
# schueler_klasse: A6B
# ad_neue_ad_str_haus_nr: Geisbergstraße|5
# ad_neue_ad_plz: 28211
# ad_neue_ad_stadt: Bremen
# ad_erzieher_name: Schubert
# ad_erzieher_vorname: Thomas
# ad_erzieher_tel: 5804474
# ad_erzieher_email: tschubert@gmx.de
# schueler_name: Schubert
# schueler_vorname: Leni
# schueler_klasse: 6B
# ad_neue_ad_str_haus_nr: Klattenweg|2
# ad_neue_ad_plz: 28213
# ad_neue_ad_stadt: Bremen
# ad_erzieher_name: Linke
# ad_erzieher_vorname: René
# ad_erzieher_tel: 5246087
# ad_erzieher_email: linke-r@gmx.de
# schueler_name: Linke
# schueler_vorname: Alicja
# schueler_klasse: 8D
# ad_neue_ad_str_haus_nr: Petershagener|Straße|13
# ad_neue_ad_plz: 28207
# schueler_klasse: 6B
# ad_erzieher_tel: 5385826
# ad_erzieher_email: fuchs-frank-christiane@web.de
# ad_neue_ad_str_haus_nr: Hebbelstraße|2
# ad_neue_ad_plz: 28755
# ad_schueler_datum: 19.04.2024
# ad_neue_ad_stadt: Bremen
# ad_erzieher_name: Fuchs
# ad_erzieher_vorname: Christiane
# schueler_name: Fuchs
# schueler_vorname: Sönke
# schueler_klasse: 6B
# ad_erzieher_name: Hillebrand
# ad_erzieher_vorname: Stefan
# schueler_name: Hillebrand
# schueler_vorname: Lina
# ad_erzieher_tel: 1790347
# ad_erzieher_email: hillebrand74@web.de
# ad_neue_ad_str_haus_nr: Mittelsbüren|35
# ad_neue_ad_plz: 28719
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 20.04.2024
# ad_neue_ad_str_haus_nr: Delfter|Straße|13
# ad_neue_ad_plz: 28259
# ad_neue_ad_stadt: bremen
# ad_schueler_datum: 17.04.2024
# ad_erzieher_name: Schäfer
# ad_erzieher_vorname: Katja
# schueler_name: Schäfer
# schueler_vorname: Maja
# schueler_klasse: 12A
# ad_erzieher_tel: 6503524
# ad_erzieher_email: schaeferks@gmx.de
# ad_erzieher_name: Fischer
# ad_erzieher_vorname: Andrea
# ad_erzieher_tel: 9825771
# ad_erzieher_email: fischerandrea@gmx.com
# schueler_name: Fischer
# schueler_vorname: Magret
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Edithweg|3
# ad_neue_ad_plz: 28201
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 06.04.2024
# ad_erzieher_name: Gorlitz-Aumann
# ad_erzieher_vorname: Daniela
# ad_erzieher_tel: 1319227
# ad_erzieher_email: gorlitz@gmail.com
# schueler_name: Gorlitz-Aumann
# schueler_vorname: Stanislav
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Erlenstraße|50
# ad_neue_ad_plz: 28199
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 19.04.2024
# ad_erzieher_name: Buchholz
# ad_erzieher_vorname: Jens
# ad_erzieher_tel: 2178448
# ad_erzieher_email: buchholz@gmx.de
# schueler_name: Buchholz
# schueler_vorname: Adeline
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Hans-Mohrmann-Straße|20
# ad_neue_ad_plz: 28357
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 13.04.2024
# ad_erzieher_name: Kant
# ad_erzieher_vorname: Melanie
# ad_erzieher_tel: 8551566
# ad_erzieher_email: mkant@web.de
# schueler_name: Kant
# schueler_vorname: Gerta
# schueler_klasse: 8D
# ad_neue_ad_str_haus_nr: Rembrandtstraße|29
# ad_neue_ad_plz: 28209
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 23.04.2024
# ad_erzieher_tel: 3988895
# ad_erzieher_vorname: Sebastian
# ad_erzieher_name: Klein
# ad_erzieher_email: familie-klein@gmx.de
# schueler_vorname: Tim
# schueler_klasse: 6B
# schueler_name: Klein
# ad_neue_ad_str_haus_nr: Herzburger|Straße|12
# ad_neue_ad_plz: 28307
# ad_neue_ad_stadt: Bremen
# schueler_vorname: Theo
# schueler_klasse: 6B
# schueler_name: Adam
# ad_erzieher_name: Adam
# ad_erzieher_vorname: Dennis
# ad_erzieher_tel: 8143009
# ad_erzieher_email: adamd@gmx.de
# ad_neue_ad_str_haus_nr: An|der|Gete|10
# ad_neue_ad_plz: 28211
# ad_neue_ad_stadt: Bremen
# schueler_vorname: Carlotta
# schueler_klasse: 8D
# schueler_name: Wiek
# ad_neue_ad_str_haus_nr: Feuerkuhle|19
# ad_neue_ad_plz: 28207
# ad_erzieher_name: Wiek
# ad_erzieher_vorname: Florian
# ad_erzieher_tel: 9791298
# ad_erzieher_email: f-wiek@posteo.de
# ad_neue_ad_stadt: Bremen
# schueler_vorname: Lia
# schueler_klasse: 6B
# schueler_name: Harmling
# ad_erzieher_name: Harmling
# ad_erzieher_vorname: Andreas
# ad_erzieher_tel: 9661674
# ad_erzieher_email: andreas-harmling@gmx.de
# ad_neue_ad_plz: 28213
# ad_neue_ad_str_haus_nr: Hackfeldstraße|30
# ad_neue_ad_stadt: Bremen
# ad_erzieher_name: Kreusel
# ad_erzieher_vorname: Melanie
# ad_erzieher_tel: 6197581
# ad_erzieher_email: famkreusel@gmx.de
# schueler_name: Kreusel
# schueler_vorname: Milica
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Danziger|straße|8
# ad_neue_ad_plz: 28237
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 19.04.2024
# ad_erzieher_name: Güde
# ad_erzieher_vorname: Nadine
# ad_erzieher_tel: 9398968
# ad_erzieher_email: gueden@gmx.de
# schueler_name: Güda
# schueler_vorname: Insa
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Dietrichstraße|12
# ad_neue_ad_plz: 28217
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 11.04.2024
# ad_erzieher_name: Schmiedt-Müde
# ad_erzieher_vorname: Katrin
# ad_erzieher_tel: 5997621
# ad_erzieher_email: smuedek@web.de
# schueler_name: Schmiedt-Müde
# schueler_vorname: Friedrich
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Bahlumer|Weg|15
# ad_neue_ad_plz: 28277
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 20.04.2024
# ad_erzieher_name: Heydrich
# ad_erzieher_vorname: Tanja
# ad_erzieher_tel: 2053157
# ad_erzieher_email: hey@web.de
# schueler_name: Heydrich
# schueler_vorname: Anika
# schueler_klasse: 12A
# ad_neue_ad_str_haus_nr: Balgebrückstraße|20
# ad_neue_ad_plz: 28195
# ad_neue_ad_stadt: Bremen
# ad_schueler_datum: 22.04.2024
# schueler_name: Hartmann
# schueler_vorname: Sven
# schueler_klasse: 6b
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 21.04.2024
# ag_schueler_datum: 20.04.2024
# ag_auswahl_wahl_3: Fussball
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_1: Volleyball
# schueler_name: Schlosser
# schueler_vorname: Lisa
# schueler_klasse: 8D
# schueler_klasse: 6B
# schueler_vorname: Emil
# schueler_name: Korte
# ag_auswahl_wahl_1: Chor
# ag_auswahl_wahl_2: Volleyball
# ag_auswahl_wahl_3: Band
# ag_schueler_datum: 19.04.2024
# schueler_name: Schubert
# schueler_vorname: Leni
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Basketball
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Band
# ag_schueler_datum: 22.04.2024
# schueler_name: Harmling
# schueler_vorname: Lia
# schueler_klasse: 6b
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Volleyball
# ag_schueler_datum: 21.04.2024
# schueler_name: Huber
# schueler_vorname: Patrick
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Programmierung
# ag_auswahl_wahl_2: Volleyball
# ag_auswahl_wahl_3: Fussball
# ag_schueler_datum: 20.04.2024
# schueler_name: Weitzel
# schueler_vorname: Stephan
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 15.04.2024
# schueler_name: Schmidt
# schueler_vorname: Siegmund
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Volleyball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 10.04.2024
# schueler_name: Noack
# schueler_vorname: Constance
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 20.04.2024
# schueler_name: Renner
# schueler_vorname: John
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Programmierung
# ag_auswahl_wahl_2: Volleyball
# ag_auswahl_wahl_3: Robotik
# ag_schueler_datum: 05.04.2024
# ag_auswahl_wahl_1: Robotik
# schueler_klasse: 8D
# schueler_vorname: Irena
# schueler_name: Jakob
# ag_schueler_datum: 20.04.2024
# ag_auswahl_wahl_3: Fussball
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Band
# schueler_name: Linke
# schueler_vorname: Alicja
# schueler_klasse: 8D
# ag_schueler_datum: 22.04.2024
# ag_schueler_datum: 19.04.2024
# ag_auswahl_wahl_1: Programmierung
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Band
# schueler_name: Jung
# schueler_vorname: Emilia
# schueler_klasse: 6B
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Band
# ag_schueler_datum: 13.04.2024
# schueler_name: Klein
# schueler_vorname: Tim
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Programmierung
# schueler_name: Winter
# schueler_vorname: Elias
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Chor
# ag_auswahl_wahl_2: Band
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 09.04.2024
# schueler_name: Heydrich
# schueler_vorname: Anika
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 07.04.2024
# schueler_name: Adam
# schueler_vorname: Theo
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_3: Volleyball
# ag_schueler_datum: 08.04.2024
# schueler_name: Fuchs
# schueler_vorname: Sönke
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Robotik
# ag_schueler_datum: 25.04.2024
# schueler_name: Burgfried
# schueler_vorname: Levi
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_3: Volleyball
# ag_schueler_datum: 24.04.2024
# schueler_name: Anders
# schueler_vorname: Iwona
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Basketball
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 20.04.2024
# schueler_name: Kreusel
# schueler_vorname: Milica
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Band
# ag_auswahl_wahl_3: Volleyball
# ag_schueler_datum: 12.04.2024
# ag_schueler_datum: 01.04.2024
# schueler_name: Zahn
# schueler_vorname: Ivan
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Robotik
# schueler_name: Aumann
# schueler_vorname: Aline
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Volleyball
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 23.04.2024
# ag_auswahl_wahl_1: Robotik
# schueler_name: Böhm
# schueler_vorname: Matteo
# schueler_klasse: 6B
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Volleyball
# ag_schueler_datum: 27.04.2024
# schueler_name: Fabisch
# schueler_vorname: Luca
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Basketball
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 09.04.2024
# schueler_name: Gutknecht
# schueler_vorname: Hans|Georg
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Band
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 02.04.2024
# schueler_name: Güde
# schueler_vorname: Insa
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 04.04.2024
# schueler_name: Wiek
# schueler_vorname: Carlotta
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Chor
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 09.04.2024
# schueler_name: Zimmer
# schueler_vorname: Silvio
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Chor
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 26.04.2024
# schueler_name: Schäfer
# schueler_vorname: Maja
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 02.04.2024
# schueler_name: Bonbach
# schueler_vorname: Jane
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 11.04.2024
# schueler_name: Lüdtke
# schueler_vorname: Mila
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Basketball
# ag_auswahl_wahl_2: Volleyball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 07.04.2024
# schueler_vorname: Roth
# schueler_name: Emma
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Band
# ag_schueler_datum: 01.04.2024
# schueler_name: Weber
# schueler_vorname: Christian
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_3: Volleyball
# ag_schueler_datum: 16.04.2024
# ag_schueler_datum: 16.04.2024
# schueler_name: Schwital-Aumann
# schueler_vorname: Albrecht
# schueler_klasse: 8D
# ag_auswahl_wahl_1: Fussball
# ag_auswahl_wahl_2: Band
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 05.04.2024
# schueler_name: Wollmann
# schueler_vorname: Mia
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Programmierung
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 11.04.2024
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_1: Band
# schueler_name: Scmiedt-Muede
# schueler_vorname: Friedrich
# schueler_klasse: 12A
# schueler_name: Buchholz-Hering
# schueler_vorname: Wojciech
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Band
# ag_auswahl_wahl_3: Fussball
# ag_schueler_datum: 20.04.2024
# schueler_name: Finn
# schueler_vorname: Mersmann
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Basketball
# ag_auswahl_wahl_3: Chor
# ag_schueler_datum: 09.04.2024
# schueler_name: Reising-Huhn
# schueler_vorname: Silvester
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Robotik
# ag_schueler_datum: 21.04.2024
# schueler_name: Mia
# schueler_vorname: Wollmann
# schueler_klasse: 6B
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Chor
# ag_auswahl_wahl_3: Programmierung
# ag_schueler_datum: 01.04.2024
# schueler_name: Huhn
# schueler_vorname: Fabian
# schueler_klasse: 12A
# ag_schueler_datum: 30.04.2024
# ag_auswahl_wahl_1: Band
# ag_auswahl_wahl_2: Fussball
# ag_auswahl_wahl_3: Robotik
# schueler_vorname: Gunnar
# ag_schueler_datum: 24.04.2024
# schueler_name: Dussen
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Robotik
# ag_auswahl_wahl_2: Band
# ag_auswahl_wahl_3: Programmierung
# schueler_name: Reising
# schueler_vorname: Verena
# schueler_klasse: 12A
# ag_auswahl_wahl_1: Basketball
# ag_auswahl_wahl_2: Robotik
# ag_auswahl_wahl_3: Fussball
# ag_schueler_datum: 12.04.2024
